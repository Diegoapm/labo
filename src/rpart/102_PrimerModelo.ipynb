# %% [markdown]
# Arbol elemental con libreria  rpart

# %% [markdown]
# #Debe tener instaladas las librerias  data.table  ,  rpart   y rpart.plot

# %%
#cargo las librerias que necesito
require("data.table")
require("rpart")
require("rpart.plot")
# Out:
# Loading required package: data.table
#
# Loading required package: rpart
#
# Loading required package: rpart.plot

# %%
#Aqui se debe poner la carpeta de SU computadora local
setwd("C:\\Users\\Administrator\\Desktop\\datamining\\")  #Establezco el Working Directory

# %% [markdown]
# cargo los datos de 202009 que es donde voy a ENTRENAR el modelo

# %%
dtrain  <- fread("C:/Users/Administrator/Desktop/datamining/datasets/paquete_premium_202011.csv")

# %% [markdown]
# genero el modelo,  aqui se construye el arbol

# %%
modelo  <- rpart("clase_ternaria ~ .",
                 data = dtrain,
                 xval=0,
                 cp=        -0.3,  #esto significa no limitar la complejidad de los splits
                 minsplit=  100,   #minima cantidad de registros para que se haga el split
                 minbucket=   1,   #tamaño minimo de una hoja
                 maxdepth=   10 )  #PRUEBO  una profundidad de 10

# %% [markdown]
# Ahora grafico el arbol, va a ser muy frondoso porque la profundidad es de 10

# %%
prp(modelo, extra=101, digits=5, branch=1, type=4, varlen=0, faclen=0)
# Out:
# Warning message:
# "labs do not fit even at cex 0.15, there may be some overplotting"
# plot without title

# %%
#Ahora aplico al modelo  a los datos de 202101  y genero la salida para kaggle

# %% [markdown]
# #cargo los datos de 202011, que es donde voy a APLICAR el modelo

# %%
dapply  <- fread("./datasets/paquete_premium_202101.csv")

# %% [raw]
# #aplico el modelo a los datos nuevos

# %%
prediccion  <- predict( modelo, dapply , type = "prob") #aplico el modelo

# %% [markdown]
# prediccion es una matriz con TRES columnas, llamadas "BAJA+1", "BAJA+2"  y "CONTINUA"
# cada columna es el vector de probabilidades

# %% [markdown]
# agrego a dapply una columna nueva que es la probabilidad de BAJA+2

# %%
dapply[ , prob_baja2 := prediccion[, "BAJA+2"] ]

# %% [markdown]
# solo le envio estimulo a los registros con probabilidad de BAJA+2 mayor  a  1/60

# %%
dapply[ , Predicted  := as.numeric(prob_baja2 > 1/60) ]

# %% [markdown]
# genero un dataset con las dos columnas que me interesan

# %%
entrega  <- dapply[   , list(numero_de_cliente, Predicted) ] #genero la salida

# %% [markdown]
# #Finalmente genero el archivo para Kaggle

# %%
#creo la carpeta donde va el experimento

# %%
dir.create( "C:/Users/Administrator/Desktop/datamining/labo/exp/" ) 
dir.create( "C:/Users/Administrator/Desktop/datamining/labo/exp/KA2002" )
# Out:
# Warning message in dir.create("C:/Users/Administrator/Desktop/datamining/labo/exp/"):
# "'C:\Users\Administrator\Desktop\datamining\labo\exp' already exists"

# %% [markdown]
# grabo el dataset

# %%
fwrite( entrega, 
        file= "C:/Users/Administrator/Desktop/datamining/labo/exp/KA2002/K102_001.csv", 
        sep= "," )
